# %% [markdown]
# <a href="https://colab.research.google.com/github/MayerT1/Prithvi_DEV/blob/main/PrithviWxC_inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# dev

# %%
# !git clone https://github.com/NASA-IMPACT/Prithvi-WxC.git
# Out:
# Cloning into 'Prithvi-WxC'...
# remote: Enumerating objects: 520, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 520 (delta 119), reused 121 (delta 89), pack-reused 337 (from 2)
# Receiving objects: 100% (520/520), 64.41 MiB | 29.43 MiB/s, done.
# Resolving deltas: 100% (262/262), done.

# %%
# %cd Prithvi-WxC
# !pip install -e .
# Out:
# /content/Prithvi-WxC
# Obtaining file:///content/Prithvi-WxC
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: h5py~=3.3 in /usr/local/lib/python3.12/dist-packages (from PrithviWxC==1.0.0) (3.15.1)
# Requirement already satisfied: numpy~=1.26 in /usr/local/lib/python3.12/dist-packages (from PrithviWxC==1.0.0) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from PrithviWxC==1.0.0) (2.2.2)
# Requirement already satisfied: torch>=2.2 in /usr/local/lib/python3.12/dist-packages (from PrithviWxC==1.0.0) (2.8.0+cu126)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from PrithviWxC==1.0.0) (25.0)
# Requirement already satisfied: tqdm>=4.66.4 in /usr/local/lib/python3.12/dist-packages (from PrithviWxC==1.0.0) (4.67.1)
# Requirement already satisfied: xarray>=2024.3.0 in /usr/local/lib/python3.12/dist-packages (from PrithviWxC==1.0.0) (2025.10.1)
# Requirement already satisfied: h5netcdf>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from PrithviWxC==1.0.0) (1.7.2)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/dist-packages (from PrithviWxC==1.0.0) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from PrithviWxC==1.0.0) (2.32.4)
# Requirement already satisfied: requests-cache in /usr/local/lib/python3.12/dist-packages (from PrithviWxC==1.0.0) (1.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from PrithviWxC==1.0.0) (1.16.2)
# Requirement already satisfied: huggingface_hub>=0.25 in /usr/local/lib/python3.12/dist-packages (from PrithviWxC==1.0.0) (0.35.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25->PrithviWxC==1.0.0) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25->PrithviWxC==1.0.0) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25->PrithviWxC==1.0.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25->PrithviWxC==1.0.0) (1.1.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->PrithviWxC==1.0.0) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->PrithviWxC==1.0.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->PrithviWxC==1.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->PrithviWxC==1.0.0) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->PrithviWxC==1.0.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->PrithviWxC==1.0.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->PrithviWxC==1.0.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->PrithviWxC==1.0.0) (2025.10.5)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache->PrithviWxC==1.0.0) (25.4.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache->PrithviWxC==1.0.0) (25.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache->PrithviWxC==1.0.0) (4.5.0)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.12/dist-packages (from requests-cache->PrithviWxC==1.0.0) (2.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->PrithviWxC==1.0.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.2->PrithviWxC==1.0.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.2->PrithviWxC==1.0.0) (3.0.3)
# Building wheels for collected packages: PrithviWxC
#   Building editable for PrithviWxC (pyproject.toml) ... done
#   Created wheel for PrithviWxC: filename=prithviwxc-1.0.0-py3-none-any.whl size=2151 sha256=8a1bf48e8c420503ecca614440013c921a791771238c47cc254a8917419d5054
#   Stored in directory: /tmp/pip-ephem-wheel-cache-svgx691r/wheels/3a/52/7b/266591a511489684fc92485f033443e97afd4aedf013889a3e
# Successfully built PrithviWxC
# Installing collected packages: PrithviWxC
#   Attempting uninstall: PrithviWxC
#     Found existing installation: PrithviWxC 1.0.0
#     Uninstalling PrithviWxC-1.0.0:
#       Successfully uninstalled PrithviWxC-1.0.0
# Successfully installed PrithviWxC-1.0.0

# %%
from PrithviWxC.dataloaders.merra2 import Merra2Dataset

# %% [markdown]
# # PrithviWxC
#
# This notebook will walk you through how to construct the model,
# load the weights, build the dataset, and use the model for inference.

# %%
import random
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
from huggingface_hub import hf_hub_download, snapshot_download

# %% [markdown]
# We now configure the backends and torch states, including setting the seeds for the RNGs.

# %%
torch.jit.enable_onednn_fusion(True)
if torch.cuda.is_available():
    print(f"Using device: {torch.cuda.get_device_name()}")
    torch.backends.cudnn.benchmark = True
    torch.backends.cudnn.deterministic = True

random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.manual_seed(42)
np.random.seed(42)
# Out:
# Using device: Tesla T4

# %% [markdown]
# The model has approximately 2.3 billion parameters, so it
# requires reasonable computational resources, but it is possible
# to run it on a CPU.

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %% [markdown]
# ## Dataloader
# ### Variables and times
#
# With the environment ready to go, we now need to set up the task.
# The core model expects a fixed set of variables from the MERRA-2
# dataset, which are prescribed below. The variables are comprised
# of surface variables, surface static variables, and variables at
# various vertical levels within the atmosphere. More details on the
# MERRA-2 dataset can be found
# [here](https://gmao.gsfc.nasa.gov/reanalysis/MERRA-2/).
#
# The MERRA-2 dataset includes data at longitudes of $-180^\circ$
# and $+180^\circ$. This represents duplicate data, so we set a
# padding variable to remove it.
#
# The input to the core model consists of these variables at two
# different times. The time difference in hours between these samples
# is passed to the model and set in the input_time variable.
#
# The model's task is to predict the fixed set of variables at a
# target time, given the input data.
#
# For example, if the input times are 0900 and 1200, resulting in
# an input_time of -3, then a lead_time of 6 would result in a
# target time of 1800.

# %%
surface_vars = [
    "EFLUX",
    "GWETROOT",
    "HFLUX",
    "LAI",
    "LWGAB",
    "LWGEM",
    "LWTUP",
    "PS",
    "QV2M",
    "SLP",
    "SWGNT",
    "SWTNT",
    "T2M",
    "TQI",
    "TQL",
    "TQV",
    "TS",
    "U10M",
    "V10M",
    "Z0M",
]
static_surface_vars = ["FRACI", "FRLAND", "FROCEAN", "PHIS"]
vertical_vars = ["CLOUD", "H", "OMEGA", "PL", "QI", "QL", "QV", "T", "U", "V"]
levels = [
    34.0,
    39.0,
    41.0,
    43.0,
    44.0,
    45.0,
    48.0,
    51.0,
    53.0,
    56.0,
    63.0,
    68.0,
    71.0,
    72.0,
]
padding = {"level": [0, 0], "lat": [0, -1], "lon": [0, 0]}

lead_times = [18]  # This varibale can be change to change the task
input_times = [-6]  # This varibale can be change to change the task

variable_names = surface_vars + [
    f'{var}_level_{level}' for var in vertical_vars for level in levels
]

# %% [markdown]
# ### Data file
# MERRA-2 data is available from 1980 to the present day,
# at 3-hour temporal resolution. The dataloader we have provided
# expects the surface data and vertical data to be saved in
# separate files, and when provided with the directories, will
# search for the relevant data that falls within the provided time range.

# %%
mkdir /content/Prithvi-WxC/data/merra-2

# %%
# time_range = ("2020-01-01T00:00:00", "2020-01-02T05:59:59")

# surf_dir = Path("../data/merra-2")
# snapshot_download(
#     repo_id="ibm-nasa-geospatial/Prithvi-WxC-1.0-2300M",
#     allow_patterns="merra-2/MERRA2_sfc_2020010[1].nc",
#     local_dir="../data",
# )

# vert_dir = Path("../data/merra-2")
# snapshot_download(
#     repo_id="ibm-nasa-geospatial/Prithvi-WxC-1.0-2300M",
#     allow_patterns="merra-2/MERRA_pres_2020010[1].nc",
#     local_dir="../data",
# )


time_range = ("2020-01-01T00:00:00", "2020-01-02T05:59:59")

# surf_dir = Path("../data/merra-2")
surf_dir = Path("/content/Prithvi-WxC/data/merra-2")
snapshot_download(
    repo_id="ibm-nasa-geospatial/Prithvi-WxC-1.0-2300M",
    allow_patterns="merra-2/MERRA2_sfc_2020010[1].nc",
    local_dir="/content/Prithvi-WxC/data/",
)

vert_dir = Path("/content/Prithvi-WxC/data/merra-2")
snapshot_download(
    repo_id="ibm-nasa-geospatial/Prithvi-WxC-1.0-2300M",
    allow_patterns="merra-2/MERRA_pres_2020010[1].nc",
    local_dir="/content/Prithvi-WxC/data/",
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# merra-2/MERRA2_sfc_20200101.nc:   0%|          | 0.00/102M [00:00<?, ?B/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# merra-2/MERRA_pres_20200101.nc:   0%|          | 0.00/337M [00:00<?, ?B/s]
# '/content/Prithvi-WxC/data'

# %% [markdown]
# ### Climatology
# The PrithviWxC model was trained to calculate the output by
# producing a perturbation to the climatology at the target time.
#  This mode of operation is set via the `residual=climate` option.
#  This was chosen as climatology is typically a strong prior for
#  long-range prediction. When using the `residual=climate` option,
#  we have to provide the dataloader with the path of the
#  climatology data.

# %%
# !pwd
# Out:
# /content/Prithvi-WxC

# %%
mkdir /content/Prithvi-WxC/data/climatology

# %%
surf_clim_dir = Path("/content/Prithvi-WxC/data/climatology")
snapshot_download(
    repo_id="ibm-nasa-geospatial/Prithvi-WxC-1.0-2300M",
    allow_patterns="climatology/climate_surface_doy00[1]*.nc",
    local_dir="/content/Prithvi-WxC/data/",
)

vert_clim_dir = Path("/content/Prithvi-WxC/data/climatology")
snapshot_download(
    repo_id="ibm-nasa-geospatial/Prithvi-WxC-1.0-2300M",
    allow_patterns="climatology/climate_vertical_doy00[1]*.nc",
    local_dir="/content/Prithvi-WxC/data/",
)
# Out:
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# climatology/climate_surface_doy001_hour0(…):   0%|          | 0.00/20.8M [00:00<?, ?B/s]
# climatology/climate_surface_doy001_hour2(…):   0%|          | 0.00/20.8M [00:00<?, ?B/s]
# climatology/climate_surface_doy001_hour1(…):   0%|          | 0.00/20.8M [00:00<?, ?B/s]
# climatology/climate_surface_doy001_hour0(…):   0%|          | 0.00/20.8M [00:00<?, ?B/s]
# climatology/climate_surface_doy001_hour0(…):   0%|          | 0.00/20.8M [00:00<?, ?B/s]
# climatology/climate_surface_doy001_hour1(…):   0%|          | 0.00/20.8M [00:00<?, ?B/s]
# climatology/climate_surface_doy001_hour1(…):   0%|          | 0.00/20.8M [00:00<?, ?B/s]
# climatology/climate_surface_doy001_hour0(…):   0%|          | 0.00/20.8M [00:00<?, ?B/s]
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# climatology/climate_vertical_doy001_hour(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# climatology/climate_vertical_doy001_hour(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# climatology/climate_vertical_doy001_hour(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# climatology/climate_vertical_doy001_hour(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# climatology/climate_vertical_doy001_hour(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# climatology/climate_vertical_doy001_hour(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# climatology/climate_vertical_doy001_hour(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# climatology/climate_vertical_doy001_hour(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# '/content/Prithvi-WxC/data'

# %% [markdown]
# ### Postion encoding
# Position data is included in the data passed to the model,
# as this allows the attention mechanism to determine data
# locality rather than explicit or implicit data connections.
# The position data is encoded in the model with two possible
# options, fourier or absolute. As these encoding options
# require different treatment within the data loader, the
# chosen option is set here.

# %%
positional_encoding = "fourier"

# %% [markdown]
# ### Dataset init
# We can now instantiate the MERRA2 Dataset class provided.

# %%
from PrithviWxC.dataloaders.merra2 import Merra2Dataset

dataset = Merra2Dataset(
    time_range=time_range,
    lead_times=lead_times,
    input_times=input_times,
    data_path_surface=surf_dir,
    data_path_vertical=vert_dir,
    climatology_path_surface=surf_clim_dir,
    climatology_path_vertical=vert_clim_dir,
    surface_vars=surface_vars,
    static_surface_vars=static_surface_vars,
    vertical_vars=vertical_vars,
    levels=levels,
    positional_encoding=positional_encoding,
)
# assert len(dataset) > 0, "There doesn't seem to be any valid data."

# %% [markdown]
# ## The model
# We are now ready to build the mdoel.
# ### Scalers
# Additionally, the model takes as static parameters the mean
# and variance values of the input variables and the variance
# values of the target difference, i.e., the variance between
# climatology and instantaneous variables. We have provided
# data files containing these values, and here we load this data.

# %%
from PrithviWxC.dataloaders.merra2 import (
    input_scalers,
    output_scalers,
    static_input_scalers,
)

surf_in_scal_path = Path("/content/Prithvi-WxC/data/climatology/musigma_surface.nc")
hf_hub_download(
    repo_id="ibm-nasa-geospatial/Prithvi-WxC-1.0-2300M",
    filename=f"climatology/{surf_in_scal_path.name}",
    local_dir="/content/Prithvi-WxC/data/",
)

vert_in_scal_path = Path("/content/Prithvi-WxC/data/climatology/musigma_vertical.nc")
hf_hub_download(
    repo_id="ibm-nasa-geospatial/Prithvi-WxC-1.0-2300M",
    filename=f"climatology/{vert_in_scal_path.name}",
    local_dir="/content/Prithvi-WxC/data/",
)

surf_out_scal_path = Path("/content/Prithvi-WxC/data/climatology/anomaly_variance_surface.nc")
hf_hub_download(
    repo_id="ibm-nasa-geospatial/Prithvi-WxC-1.0-2300M",
    filename=f"climatology/{surf_out_scal_path.name}",
    local_dir="/content/Prithvi-WxC/data/",
)

vert_out_scal_path = Path("/content/Prithvi-WxC/data/climatology/anomaly_variance_vertical.nc")
hf_hub_download(
    repo_id="ibm-nasa-geospatial/Prithvi-WxC-1.0-2300M",
    filename=f"climatology/{vert_out_scal_path.name}",
    local_dir="/content/Prithvi-WxC/data/",
)

in_mu, in_sig = input_scalers(
    surface_vars,
    vertical_vars,
    levels,
    surf_in_scal_path,
    vert_in_scal_path,
)

output_sig = output_scalers(
    surface_vars,
    vertical_vars,
    levels,
    surf_out_scal_path,
    vert_out_scal_path,
)

static_mu, static_sig = static_input_scalers(
    surf_in_scal_path,
    static_surface_vars,
)
# Out:
# climatology/musigma_surface.nc:   0%|          | 0.00/24.7k [00:00<?, ?B/s]
# climatology/musigma_vertical.nc:   0%|          | 0.00/25.0k [00:00<?, ?B/s]
# climatology/anomaly_variance_surface.nc:   0%|          | 0.00/11.5k [00:00<?, ?B/s]
# climatology/anomaly_variance_vertical.nc:   0%|          | 0.00/18.6k [00:00<?, ?B/s]

# %% [markdown]
# ### Task and additional configs
# As previously mentioned, the PrithviWxC model's pretext task
# involved predicting the desired variable at a specific lead
# time. This was achieved by calculating the difference (delta)
# compared to the climatological average at that time. This
# operational mode is activated using the residual flag. Although
# the model includes additional residual options, the core model
# weights were not trained using these modes.
#
# Additionally, for training and evaluation, it is possible to
# mask tokens in the model. The masking occurs after tokenization,
# prior to the encoder layers. The model utilizes multi-axis
# attention, with data broken down into a hierarchy of local and
# global patches. Consequently, masking can be configured to mask
# either small local patches or larger global patches. This
# configuration is achieved via the `masking_mode` flag. It is
# possible to set `masking_mode=both`. This does not mix the modes
# but rather allows both modes to be used and swapped between,
# primarily for training purposes. For this demonstration, we will
# adjust the masking ratio to showcase the reconstruction
# capabilities of the model.
#
# Finally, we can set up shifting. Primarily utilized in the
# decoder, this enables alternate shifting of the attention
# windows, similar to the SWIN model. This option necessitates
# an even number of decoder blocks and is incompatible with the
# encoder when masking is also employed.

# %%
residual = "climate"
masking_mode = "global"
encoder_shifting = True
decoder_shifting = True
masking_ratio = 0.0

# %% [markdown]
# ### Model init
# We now have all the pieces to build the model. If you are
# using the pretrained weights, a number of the model
# hyperparameters are predetermined and included below. With
# this configuration, the model will have approximately 2.3
# billion parameters. Therefore, if you want to train the fully
# unfrozen model, you will likely need to use a model distribution
# approach, such as fully shared data parallelism (FSDP). To
# further reduce the memory usage of the model when gradients are
# required, there are two variables — `checkpoint_encoder` and
# `checkpoint_decoder` — which enable activation checkpointing of
# desired transformer layers.

# %%
import yaml

from PrithviWxC.model import PrithviWxC

hf_hub_download(
    repo_id="ibm-nasa-geospatial/Prithvi-WxC-1.0-2300M",
    filename="config.yaml",
    local_dir="/content/Prithvi-WxC/data",
)

with open("/content/Prithvi-WxC/data/config.yaml", "r") as f:
    config = yaml.safe_load(f)

model = PrithviWxC(
    in_channels=config["params"]["in_channels"],
    input_size_time=config["params"]["input_size_time"],
    in_channels_static=config["params"]["in_channels_static"],
    input_scalers_mu=in_mu,
    input_scalers_sigma=in_sig,
    input_scalers_epsilon=config["params"]["input_scalers_epsilon"],
    static_input_scalers_mu=static_mu,
    static_input_scalers_sigma=static_sig,
    static_input_scalers_epsilon=config["params"][
        "static_input_scalers_epsilon"
    ],
    output_scalers=output_sig**0.5,
    n_lats_px=config["params"]["n_lats_px"],
    n_lons_px=config["params"]["n_lons_px"],
    patch_size_px=config["params"]["patch_size_px"],
    mask_unit_size_px=config["params"]["mask_unit_size_px"],
    mask_ratio_inputs=masking_ratio,
    mask_ratio_targets=0.0,
    embed_dim=config["params"]["embed_dim"],
    n_blocks_encoder=config["params"]["n_blocks_encoder"],
    n_blocks_decoder=config["params"]["n_blocks_decoder"],
    mlp_multiplier=config["params"]["mlp_multiplier"],
    n_heads=config["params"]["n_heads"],
    dropout=config["params"]["dropout"],
    drop_path=config["params"]["drop_path"],
    parameter_dropout=config["params"]["parameter_dropout"],
    residual=residual,
    masking_mode=masking_mode,
    encoder_shifting=encoder_shifting,
    decoder_shifting=decoder_shifting,
    positional_encoding=positional_encoding,
    checkpoint_encoder=[],
    checkpoint_decoder=[],
)
# Out:
# config.yaml:   0%|          | 0.00/428 [00:00<?, ?B/s]

# %% [markdown]
# ### Load weights
# We have provided unshared pretrained weights for the model,
# which can now be loaded. The model can then be transferred
# to the requested device.

# %%
mkdir /content/Prithvi-WxC/data/weights

# %%
weights_path = Path("/content/Prithvi-WxC/data/weights/prithvi.wxc.2300m.v1.pt")
hf_hub_download(
    repo_id="ibm-nasa-geospatial/Prithvi-WxC-1.0-2300M",
    filename=weights_path.name,
    local_dir="/content/Prithvi-WxC/data/weights",
)

state_dict = torch.load(weights_path, weights_only=False)
if "model_state" in state_dict:
    state_dict = state_dict["model_state"]
model.load_state_dict(state_dict, strict=True)

if (hasattr(model, "device") and model.device != device) or not hasattr(
    model, "device"
):
    model = model.to(device)
# Out:
# prithvi.wxc.2300m.v1.pt:   0%|          | 0.00/28.4G [00:00<?, ?B/s]

# %% [markdown]
# ## Inference
# We are now ready to perform inference on the model. The data
# returned from the dataset class requires additional
# preprocessing; therefore, after polling the dataset, we process
# the data using the `preproc` function. This processed data is
# then transferred to the device. To recover the masking, we can
# save the torch RNG state and use it later. Finally, we run the
# model in evaluation mode without generating the gradient graph.

# %%
from PrithviWxC.dataloaders.merra2 import preproc

data = next(iter(dataset))
batch = preproc([data], padding)

for k, v in batch.items():
    if isinstance(v, torch.Tensor):
        batch[k] = v.to(device)

rng_state_1 = torch.get_rng_state()
with torch.no_grad():
    model.eval()
    out = model(batch)

# %% [markdown]
# ## Plotting

# %%
t2m = out[0, variable_names.index("T2M")].cpu().numpy()

lat = np.linspace(-90, 90, out.shape[-2])
lon = np.linspace(-180, 180, out.shape[-1])
X, Y = np.meshgrid(lon, lat)

plt.contourf(X, Y, t2m, 100)
plt.gca().set_aspect("equal")
plt.show()

# %%
tqv = out[0, variable_names.index("TQV")].cpu().numpy()

lat = np.linspace(-90, 90, out.shape[-2])
lon = np.linspace(-180, 180, out.shape[-1])
X, Y = np.meshgrid(lon, lat)

plt.contourf(X, Y, tqv, 100)
plt.gca().set_aspect("equal")
plt.show()

# %%
u10m = out[0, variable_names.index("U10M")].cpu().numpy()

lat = np.linspace(-90, 90, out.shape[-2])
lon = np.linspace(-180, 180, out.shape[-1])
X, Y = np.meshgrid(lon, lat)

plt.contourf(X, Y, u10m, 100)
plt.gca().set_aspect("equal")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1473571838.py in <cell line: 0>()
# ----> 1 u10m = out[0, variable_names.index("U10M")].cpu().numpy()
#       2
#       3 lat = np.linspace(-90, 90, out.shape[-2])
#       4 lon = np.linspace(-180, 180, out.shape[-1])
#       5 X, Y = np.meshgrid(lon, lat)
#
# NameError: name 'out' is not defined
